# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import pylab
import requests
import json

# %%
#read in csvs for 2017 stats, cost of living index, and physician demographic info
data_2017 = os.path.join('Resources', '2017.csv')
data_2017 = pd.read_csv(data_2017)
cost = os.path.join('Resources', 'cost_of_living_state.csv')
physician_data = os.path.join('Resources', "physician_data.csv")
physician_data = pd.read_csv(physician_data)
cost_living = pd.read_csv(cost)
data_2017.head()
# Out:
#                                       DRG Definition  Provider Id  \
# 0  023 - CRANIOTOMY W MAJOR DEVICE IMPLANT OR ACU...        10001
# 1  025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL P...        10001
# 2  027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL P...        10001
# 3                037 - EXTRACRANIAL PROCEDURES W MCC        10001
# 4                 038 - EXTRACRANIAL PROCEDURES W CC        10001
#
#                       Provider Name Provider Street Address Provider City  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 1  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 2  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 3  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 4  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
#
#   Provider State  Provider Zip Code  \
# 0             AL              36301
# 1             AL              36301
# 2             AL              36301
# 3             AL              36301
# 4             AL              36301
#
#   Hospital Referral Region (HRR) Description  Total Discharges  \
# 0                                AL - Dothan                28
# 1                                AL - Dothan                32
# 2                                AL - Dothan                11
# 3                                AL - Dothan                12
# 4                                AL - Dothan                17
#
#    Average Covered Charges  Average Total Payments  Average Medicare Payments
# 0                117117.79                25823.71                   24057.39
# 1                 98357.56                20688.34                   19791.41
# 2                 69153.55                11811.18                    8194.36
# 3                100427.33                19134.00                   18154.00
# 4                 58199.47                 8519.47                    6714.88

# %%
#number of enrollees by state and type of plan
enroll_data = os.path.join('Resources', 'Medicare_Enrollment.csv')
enrollees = pd.read_csv(enroll_data)

# %%
#create DF and convert to numeric
enrollees_df = pd.DataFrame(enrollees)
enrollees_df[["Original Medicare", 
           "Medicare Advantage & Other Health Plans"]] = enrollees_df[[ 
                                                        "Original Medicare", 
                                                        "Medicare Advantage & Other Health Plans"]].apply(pd.to_numeric)
enrollees_df.head()
# Out:
#         State    Total  Original Medicare  \
# 0     Alabama   935026             568207
# 1      Alaska    80134              78805
# 2     Arizona  1122760             650109
# 3    Arkansas   572605             436607
# 4  California  5314498            2825802
#
#    Medicare Advantage & Other Health Plans
# 0                                   366819
# 1                                     1329
# 2                                   472650
# 3                                   135999
# 4                                  2488697

# %%
#add a column calculating what % of people are on premium plans
enrollees_df['Percentage of Medicare Advantage'] = round((enrollees_df['Medicare Advantage & Other Health Plans'] / 
                                                   enrollees_df['Total']) * 100, 1)
enrollees_df.head()
# Out:
#         State    Total  Original Medicare  \
# 0     Alabama   935026             568207
# 1      Alaska    80134              78805
# 2     Arizona  1122760             650109
# 3    Arkansas   572605             436607
# 4  California  5314498            2825802
#
#    Medicare Advantage & Other Health Plans  Percentage of Medicare Advantage
# 0                                   366819                              39.2
# 1                                     1329                               1.7
# 2                                   472650                              42.1
# 3                                   135999                              23.8
# 4                                  2488697                              46.8

# %%
names = []
for name in enrollees["State"]: 
    names.append(name)
#chart showing how many Medicare recipients per state
plt.figure(figsize=(15,10))
x_axis = np.arange(len(enrollees_df["State"]))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, names, rotation="vertical")
plt.bar(x_axis, enrollees_df["Total"])
plt.grid()
plt.xlabel("State")
plt.ylabel("Number of Medicare Enrollees")
plt.title("Medicare Enrollees by State")
plt.tight_layout()
plt.savefig("Medicare enrollees by State")

# %%
#for ease in converting states to abbreviations for easier merging later
us_state_abbrev = [{
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Palau': 'PW',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}]

abbrevs_df = pd.DataFrame(us_state_abbrev).T
abbrevs_df = abbrevs_df.reset_index().rename(columns={0: 'provider_state', 'index':'State'})

# %%
#work on this later- a different way to convert state names

# for state in cost_living['State']:
#     for name in abbrevs_df['State']:
#         if state == name:
#             cost_living['State'] = abbrevs_df.loc['Abbreviation']
            
# cost_living

# %%
physician_data.head()
# Out:
#         Location  Primary Care Physicians  Specialist Physicians      Total
# 0  United States                 479856.0               525439.0  1005295.0
# 1        Alabama                   5863.0                 6342.0    12205.0
# 2         Alaska                   1054.0                  846.0     1900.0
# 3        Arizona                   8537.0                 9269.0    17806.0
# 4       Arkansas                   3513.0                 3637.0     7150.0

# %%
physician_data = physicain_data = physician_data.rename(columns={"Location": "State", "Primary Care Physicians": "primary_care_physicians", "Specialist Physicians": "specialist_physicians"})

# %%
physician_data = pd.merge(physician_data, abbrevs_df, on="State")
physician_data.head()
# Out:
#         State  primary_care_physicians  specialist_physicians     Total  \
# 0     Alabama                   5863.0                 6342.0   12205.0
# 1      Alaska                   1054.0                  846.0    1900.0
# 2     Arizona                   8537.0                 9269.0   17806.0
# 3    Arkansas                   3513.0                 3637.0    7150.0
# 4  California                  54135.0                58771.0  112906.0
#
#   provider_state
# 0             AL
# 1             AK
# 2             AZ
# 3             AR
# 4             CA

# %%
cost_enrollees_merge = pd.merge(cost_living, enrollees_df, how='outer', on='State')
cost_enrollees_merge.head()
# Out:
#    costIndex        State  costRank  groceryCost  housingCost  utilitiesCost  \
# 0          1  Mississippi      86.1         91.6         70.1           89.1
# 1          2     Arkansas      86.9         92.0         73.9           91.8
# 2          3     Oklahoma      87.0         95.4         71.9           94.1
# 3          4     Missouri      87.1         96.6         70.6           99.6
# 4          5   New Mexico      87.5        100.9         77.7           87.9
#
#    transportationCost  miscCost    Total  Original Medicare  \
# 0                89.2      91.4   545769             446980
# 1                83.6      85.6   572605             436607
# 2                89.5      93.2   646237             518215
# 3                87.3      95.7  1092124             713966
# 4                91.6     100.1   358531             224594
#
#    Medicare Advantage & Other Health Plans  Percentage of Medicare Advantage
# 0                                    98789                              18.1
# 1                                   135999                              23.8
# 2                                   128021                              19.8
# 3                                   378158                              34.6
# 4                                   133937                              37.4

# %%
cost_abbrev = pd.merge(cost_enrollees_merge, abbrevs_df, how='left')
cost_abbrev.head()
# Out:
#    costIndex        State  costRank  groceryCost  housingCost  utilitiesCost  \
# 0          1  Mississippi      86.1         91.6         70.1           89.1
# 1          2     Arkansas      86.9         92.0         73.9           91.8
# 2          3     Oklahoma      87.0         95.4         71.9           94.1
# 3          4     Missouri      87.1         96.6         70.6           99.6
# 4          5   New Mexico      87.5        100.9         77.7           87.9
#
#    transportationCost  miscCost    Total  Original Medicare  \
# 0                89.2      91.4   545769             446980
# 1                83.6      85.6   572605             436607
# 2                89.5      93.2   646237             518215
# 3                87.3      95.7  1092124             713966
# 4                91.6     100.1   358531             224594
#
#    Medicare Advantage & Other Health Plans  Percentage of Medicare Advantage  \
# 0                                    98789                              18.1
# 1                                   135999                              23.8
# 2                                   128021                              19.8
# 3                                   378158                              34.6
# 4                                   133937                              37.4
#
#   provider_state
# 0             MS
# 1             AR
# 2             OK
# 3             MO
# 4             NM

# %%
#drop columns that we won't need
sorted_df = cost_abbrev.sort_values(['provider_state'])
sorted_df = sorted_df.drop(columns=['costIndex', 'State'])
sorted_df.head()
# Out:
#     costRank  groceryCost  housingCost  utilitiesCost  transportationCost  \
# 44     129.9        134.2        133.9          154.2               130.8
# 10      89.3         97.4         71.5          103.3                88.6
# 1       86.9         92.0         73.9           91.8                83.6
# 23      97.0         96.9         91.7          107.4               109.6
# 48     151.7        121.4        227.3          117.7               138.9
#
#     miscCost    Total  Original Medicare  \
# 44     150.9    80134              78805
# 10      90.8   935026             568207
# 1       85.6   572605             436607
# 23      94.7  1122760             650109
# 48     114.5  5314498            2825802
#
#     Medicare Advantage & Other Health Plans  Percentage of Medicare Advantage  \
# 44                                     1329                               1.7
# 10                                   366819                              39.2
# 1                                    135999                              23.8
# 23                                   472650                              42.1
# 48                                  2488697                              46.8
#
#    provider_state
# 44             AK
# 10             AL
# 1              AR
# 23             AZ
# 48             CA

# %%
#set up scatter plot to show relationship between total cost of living and enrollees on premium plans
plt.scatter(sorted_df['costRank'], sorted_df['Percentage of Medicare Advantage'], edgecolor='k')
plt.grid(True)
plt.title('total cost of living vs percentage of Med Adv enrollees (by state)')
plt.xlabel('Cost of Living')
plt.ylabel('Percentage of Medicare Advantage Enrollees')

#save and then show chart
# plt.savefig('medadvandcostliving.png')
plt.show()

# %%
# weak correlation
medadvcost = sorted_df[['costRank', 'Percentage of Medicare Advantage']]
medadvcost.corr()
# Out:
#                                   costRank  Percentage of Medicare Advantage
# costRank                          1.000000                          0.124048
# Percentage of Medicare Advantage  0.124048                          1.000000

# %%
data_2017.columns = data_2017.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
data_2017.head()
# Out:
#                                       drg_definition  provider_id  \
# 0  023 - CRANIOTOMY W MAJOR DEVICE IMPLANT OR ACU...        10001
# 1  025 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL P...        10001
# 2  027 - CRANIOTOMY & ENDOVASCULAR INTRACRANIAL P...        10001
# 3                037 - EXTRACRANIAL PROCEDURES W MCC        10001
# 4                 038 - EXTRACRANIAL PROCEDURES W CC        10001
#
#                       provider_name provider_street_address provider_city  \
# 0  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 1  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 2  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 3  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
# 4  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE        DOTHAN
#
#   provider_state  provider_zip_code hospital_referral_region_hrr_description  \
# 0             AL              36301                              AL - Dothan
# 1             AL              36301                              AL - Dothan
# 2             AL              36301                              AL - Dothan
# 3             AL              36301                              AL - Dothan
# 4             AL              36301                              AL - Dothan
#
#    total_discharges  average_covered_charges  average_total_payments  \
# 0                28                117117.79                25823.71
# 1                32                 98357.56                20688.34
# 2                11                 69153.55                11811.18
# 3                12                100427.33                19134.00
# 4                17                 58199.47                 8519.47
#
#    average_medicare_payments
# 0                   24057.39
# 1                   19791.41
# 2                    8194.36
# 3                   18154.00
# 4                    6714.88

# %%
data_2017 = data_2017[["provider_state", "provider_name", "total_discharges", "average_covered_charges", "average_total_payments", "average_medicare_payments"]]

# %%
data_2017["average_consumer_payments"] = data_2017["average_total_payments"] - data_2017["average_medicare_payments"]

# %%
data_2017.head()
# Out:
#   provider_state                     provider_name  total_discharges  \
# 0             AL  SOUTHEAST ALABAMA MEDICAL CENTER                28
# 1             AL  SOUTHEAST ALABAMA MEDICAL CENTER                32
# 2             AL  SOUTHEAST ALABAMA MEDICAL CENTER                11
# 3             AL  SOUTHEAST ALABAMA MEDICAL CENTER                12
# 4             AL  SOUTHEAST ALABAMA MEDICAL CENTER                17
#
#    average_covered_charges  average_total_payments  average_medicare_payments  \
# 0                117117.79                25823.71                   24057.39
# 1                 98357.56                20688.34                   19791.41
# 2                 69153.55                11811.18                    8194.36
# 3                100427.33                19134.00                   18154.00
# 4                 58199.47                 8519.47                    6714.88
#
#    average_consumer_payments
# 0                    1766.32
# 1                     896.93
# 2                    3616.82
# 3                     980.00
# 4                    1804.59

# %%
data_2017['total_covered_charges'] = data_2017['total_discharges'] * data_2017['average_covered_charges']
data_2017['total_payments'] = data_2017['total_discharges'] * data_2017['average_total_payments']
data_2017['total_medicare_payments'] = data_2017['total_discharges'] * data_2017['average_medicare_payments']
data_2017['total_consumer_payments'] = data_2017['total_discharges'] * data_2017['average_consumer_payments']

# %%
data_2017.head()
# Out:
#   provider_state                     provider_name  total_discharges  \
# 0             AL  SOUTHEAST ALABAMA MEDICAL CENTER                28
# 1             AL  SOUTHEAST ALABAMA MEDICAL CENTER                32
# 2             AL  SOUTHEAST ALABAMA MEDICAL CENTER                11
# 3             AL  SOUTHEAST ALABAMA MEDICAL CENTER                12
# 4             AL  SOUTHEAST ALABAMA MEDICAL CENTER                17
#
#    average_covered_charges  average_total_payments  average_medicare_payments  \
# 0                117117.79                25823.71                   24057.39
# 1                 98357.56                20688.34                   19791.41
# 2                 69153.55                11811.18                    8194.36
# 3                100427.33                19134.00                   18154.00
# 4                 58199.47                 8519.47                    6714.88
#
#    average_consumer_payments  total_covered_charges  total_payments  \
# 0                    1766.32             3279298.12       723063.88
# 1                     896.93             3147441.92       662026.88
# 2                    3616.82              760689.05       129922.98
# 3                     980.00             1205127.96       229608.00
# 4                    1804.59              989390.99       144830.99
#
#    total_medicare_payments  total_consumer_payments
# 0                673606.92                 49456.96
# 1                633325.12                 28701.76
# 2                 90137.96                 39785.02
# 3                217848.00                 11760.00
# 4                114152.96                 30678.03

# %%
#url for a dataset comparing hospital charges and outcomes for 4 different categories
base_url = "https://data.medicare.gov/resource/2kat-xip9.json?"
states = abbrevs_df['provider_state'].tolist()

# %%
#create an empty list, for loop through dataset, and pull out tuples of info
outcomes = []

for state in states:
    print(f"Getting info for the state of {state}")
    query_url = base_url + 'state=' + state
    outcomes_data = requests.get(query_url)
    outcomes_json = outcomes_data.json()
    for ind in outcomes_json:
        try:
            outcomes.append((ind['state'], ind['hospital_name'], 
                             ind['zip_code'], ind['county_name'], 
                             ind['value_of_care_display_id'], ind['value_of_care_category']))
        except:
            print(f"No state found with the abbreviation of {state}")
# Out:
# Getting info for the state of AL
# Getting info for the state of AK
# Getting info for the state of AZ
# Getting info for the state of AR
# Getting info for the state of CA
# Getting info for the state of CO
# Getting info for the state of CT
# Getting info for the state of DE
# Getting info for the state of DC
# Getting info for the state of FL
# Getting info for the state of GA
# Getting info for the state of HI
# Getting info for the state of ID
# Getting info for the state of IL
# Getting info for the state of IN
# Getting info for the state of IA
# Getting info for the state of KS
# Getting info for the state of KY
# Getting info for the state of LA
# Getting info for the state of ME
# Getting info for the state of MD
# Getting info for the state of MA
# Getting info for the state of MI
# Getting info for the state of MN
# Getting info for the state of MS
# Getting info for the state of MO
# Getting info for the state of MT
# Getting info for the state of NE
# Getting info for the state of NV
# Getting info for the state of NH
# Getting info for the state of NJ
# Getting info for the state of NM
# Getting info for the state of NY
# Getting info for the state of NC
# Getting info for the state of ND
# Getting info for the state of MP
# Getting info for the state of OH
# Getting info for the state of OK
# Getting info for the state of OR
# Getting info for the state of PW
# Getting info for the state of PA
# Getting info for the state of PR
# Getting info for the state of RI
# Getting info for the state of SC
# Getting info for the state of SD
# Getting info for the state of TN
# Getting info for the state of TX
# Getting info for the state of UT
# Getting info for the state of VT
# Getting info for the state of VI
# Getting info for the state of VA
# Getting info for the state of WA
# Getting info for the state of WV
# Getting info for the state of WI
# Getting info for the state of WY

# %%
#create df
outcomes_df = pd.DataFrame(outcomes, columns=('provider_state', 'provider_name', 'zip_code', 
                          'county_name', 'category', 'outcome_and_payment'))
#clean data by removing invalid results, etc
outcomes_df = outcomes_df[outcomes_df.outcome_and_payment != 'Not Available']
outcomes_df.head()
# Out:
#   provider_state                provider_name zip_code county_name  \
# 2             AL       COMMUNITY HOSPITAL INC    36078      ELMORE
# 3             AL             FLOWERS HOSPITAL    36305     HOUSTON
# 5             AL          PROVIDENCE HOSPITAL    36608      MOBILE
# 6             AL  BAPTIST MEDICAL CENTER EAST    36117  MONTGOMERY
# 7             AL         CLAY COUNTY HOSPITAL    36251        CLAY
#
#            category                    outcome_and_payment
# 2   MORT_PAYM_30_HF    Average Mortality and Lower Payment
# 3  MORT_PAYM_30_AMI  Average Mortality and Average Payment
# 5   MORT_PAYM_30_HF    Average Mortality and Lower Payment
# 6  MORT_PAYM_30_AMI  Average Mortality and Average Payment
# 7   MORT_PAYM_30_HF  Average Mortality and Average Payment

# %%
#split outcome_and_payment into separate columns for easier comparisons
outcomes_df[['outcome', 'payment']] = outcomes_df['outcome_and_payment'].str.split(" and ", expand=True)
outcomes_df.head()
# Out:
#   provider_state                provider_name zip_code county_name  \
# 2             AL       COMMUNITY HOSPITAL INC    36078      ELMORE
# 3             AL             FLOWERS HOSPITAL    36305     HOUSTON
# 5             AL          PROVIDENCE HOSPITAL    36608      MOBILE
# 6             AL  BAPTIST MEDICAL CENTER EAST    36117  MONTGOMERY
# 7             AL         CLAY COUNTY HOSPITAL    36251        CLAY
#
#            category                    outcome_and_payment            outcome  \
# 2   MORT_PAYM_30_HF    Average Mortality and Lower Payment  Average Mortality
# 3  MORT_PAYM_30_AMI  Average Mortality and Average Payment  Average Mortality
# 5   MORT_PAYM_30_HF    Average Mortality and Lower Payment  Average Mortality
# 6  MORT_PAYM_30_AMI  Average Mortality and Average Payment  Average Mortality
# 7   MORT_PAYM_30_HF  Average Mortality and Average Payment  Average Mortality
#
#            payment
# 2    Lower Payment
# 3  Average Payment
# 5    Lower Payment
# 6  Average Payment
# 7  Average Payment

# %%
df[~df['DB Serial'].str.contains('\*')]

# %%
mortality_outcomes = outcomes_df[~outcomes_df['outcome'].str.contains('Complications')]
mortality_outcomes.head()
# Out:
#   provider_state                provider_name zip_code county_name  \
# 2             AL       COMMUNITY HOSPITAL INC    36078      ELMORE
# 3             AL             FLOWERS HOSPITAL    36305     HOUSTON
# 5             AL          PROVIDENCE HOSPITAL    36608      MOBILE
# 6             AL  BAPTIST MEDICAL CENTER EAST    36117  MONTGOMERY
# 7             AL         CLAY COUNTY HOSPITAL    36251        CLAY
#
#            category                    outcome_and_payment            outcome  \
# 2   MORT_PAYM_30_HF    Average Mortality and Lower Payment  Average Mortality
# 3  MORT_PAYM_30_AMI  Average Mortality and Average Payment  Average Mortality
# 5   MORT_PAYM_30_HF    Average Mortality and Lower Payment  Average Mortality
# 6  MORT_PAYM_30_AMI  Average Mortality and Average Payment  Average Mortality
# 7   MORT_PAYM_30_HF  Average Mortality and Average Payment  Average Mortality
#
#            payment
# 2    Lower Payment
# 3  Average Payment
# 5    Lower Payment
# 6  Average Payment
# 7  Average Payment

# %%
#ideas: how many fall into each of 9 categories
# above average mortality and lower payment is best case scenario
av_outcome = outcomes_df.loc[outcomes_df['outcome'] == 'Average Mortality'].count()
av_outcome
# Out:
# provider_state         8363
# provider_name          8363
# zip_code               8363
# county_name            8363
# category               8363
# outcome_and_payment    8363
# outcome                8363
# payment                8363
# dtype: int64

# %%
outcomes_df.groupby(['provider_state'])['outcome'].value_counts().head()
# Out:
# provider_state  outcome
# AK              Average Mortality         28
#                 Average Complications      8
# AL              Average Mortality        172
#                 Average Complications     42
#                 Worse Mortality           12
# Name: outcome, dtype: int64

# %%
outcomes_df['payment'].value_counts()
# Out:
# Average Payment    7361
# Lower Payment      2427
# Higher Payment     1995
# Name: payment, dtype: int64

# %%
mortality_grp = mortality_outcomes.groupby(['provider_state'])['outcome'].value_counts()
mortality_df = mortality_grp.unstack()
mortality_df.fillna(0)
# Out:
# outcome         Average Mortality  Better Mortality  Worse Mortality
# provider_state
# AK                           28.0               0.0              0.0
# AL                          172.0               4.0             12.0
# AR                          142.0               0.0             14.0
# AZ                          146.0               5.0              5.0
# CA                          463.0              58.0             22.0
# CO                          140.0               3.0              1.0
# CT                           76.0               3.0              2.0
# DC                           19.0               1.0              1.0
# DE                           18.0               0.0              0.0
# FL                          431.0              24.0             36.0
# GA                          252.0               5.0              8.0
# HI                           33.0               0.0              0.0
# IA                          197.0               2.0             13.0
# ID                           55.0               0.0              4.0
# IL                          374.0              35.0             20.0
# IN                          255.0               6.0             12.0
# KS                          181.0               7.0             10.0
# KY                          193.0               2.0             18.0
# LA                          189.0               3.0              6.0
# MA                          131.0              29.0              0.0
# MD                          117.0               5.0              6.0
# ME                           80.0               1.0              5.0
# MI                          247.0              28.0              7.0
# MN                          158.0               6.0              0.0
# MO                          208.0               9.0             19.0
# MP                            2.0               0.0              0.0
# MS                          158.0               0.0             14.0
# MT                           68.0               0.0              1.0
# NC                          229.0               3.0             27.0
# ND                           52.0               1.0              1.0
# NE                          127.0               0.0              2.0
# NH                           64.0               3.0              1.0
# NJ                          168.0              19.0              4.0
# NM                           75.0               0.0              1.0
# NV                           67.0               4.0              4.0
# NY                          339.0              42.0             25.0
# OH                          327.0              31.0              7.0
# OK                          190.0               2.0             10.0
# OR                          120.0               0.0              6.0
# PA                          369.0              17.0              8.0
# PR                           52.0               0.0              1.0
# RI                           25.0               2.0              0.0
# SC                          120.0               2.0             16.0
# SD                           63.0               0.0              0.0
# TN                          208.0               2.0             14.0
# TX                          391.0              16.0              8.0
# UT                           75.0               0.0              1.0
# VA                          193.0              12.0              7.0
# VI                            6.0               0.0              0.0
# VT                           33.0               1.0              1.0
# WA                          166.0               2.0             14.0
# WI                          235.0               8.0             10.0
# WV                           97.0               2.0              3.0
# WY                           39.0               0.0              3.0

# %%
payment_grp = mortality_outcomes.groupby(['provider_state'])['payment'].value_counts()

# %%
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)

ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence
p1 = plt.bar(ind, menMeans, width)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans)


plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()
pivot_df.loc[:,['Jan','Feb', 'Mar']].plot.bar(stacked=True, color=colors, figsize=(10,7))

# %%
#create a stacked bar chart for mortality by state
# plt.figure(figsize=(15,10))
x_axis = np.arange(len(mortality_df))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, names, rotation="vertical")
colors = ['red', 'lightblue', 'green']
# avg = mortality_df['Average Mortality']
# bad = mortality_df['Worse Mortality']
# good = mortality_df['Better Mortality']

# p1 = plt.bar(x_axis, bad)
# p2 = plt.bar(x_axis, avg)
# p3 = plt.bar(x_axis, good, bottom=bad)
# plt.grid()

mortality_df.loc[:,['Worse Mortality','Average Mortality', 'Better Mortality']].plot.bar(stacked=True, figsize=(10,8), 
                                                                                        color=colors)

plt.xlabel("State")
plt.ylabel("Mortality Outcomes")
plt.title("Mortality Outcomes by State")
plt.legend(('Worse Mortality', 'Average Mortality', 'Better Mortality'))
# plt.tight_layout()
plt.savefig("Mortality by State stacked bar")

# %%
state_grouped = data_2017.groupby("provider_state").sum()
state_grouped.head()
# Out:
#                 total_discharges  average_covered_charges  \
# provider_state
# AK                          7681             2.337966e+07
# AL                        142060             2.143038e+08
# AR                         91655             1.058598e+08
# AZ                        115039             2.434176e+08
# CA                        531134             1.619089e+09
#
#                 average_total_payments  average_medicare_payments  \
# provider_state
# AK                        5.705120e+06               4.996261e+06
# AL                        4.119621e+07               3.409628e+07
# AR                        2.707915e+07               2.321937e+07
# AZ                        5.071762e+07               4.397756e+07
# CA                        2.802472e+08               2.466170e+08
#
#                 average_consumer_payments  total_covered_charges  \
# provider_state
# AK                              708859.07           6.644232e+08
# AL                             7099926.01           7.463371e+09
# AR                             3859778.17           3.637367e+09
# AZ                             6740056.79           7.735654e+09
# CA                            33630191.47           5.423888e+10
#
#                 total_payments  total_medicare_payments  \
# provider_state
# AK                1.613549e+08             1.406472e+08
# AL                1.445037e+09             1.182575e+09
# AR                9.448575e+08             8.071309e+08
# AZ                1.634324e+09             1.400898e+09
# CA                9.248171e+09             8.130260e+09
#
#                 total_consumer_payments
# provider_state
# AK                         2.070764e+07
# AL                         2.624626e+08
# AR                         1.377266e+08
# AZ                         2.334254e+08
# CA                         1.117911e+09

# %%
state_grouped["per_capita_average_total_payments"] = round(state_grouped["total_payments"]/state_grouped["total_discharges"], 2)
state_grouped["per_capita_average_medicare_payments"] = round(state_grouped["total_medicare_payments"]/state_grouped["total_discharges"], 2)
state_grouped["per_capita_average_consumer_payments"] = round(state_grouped["total_consumer_payments"]/state_grouped["total_discharges"], 2)

# %%
state_grouped.head()
# Out:
#                 total_discharges  average_covered_charges  \
# provider_state
# AK                          7681             2.337966e+07
# AL                        142060             2.143038e+08
# AR                         91655             1.058598e+08
# AZ                        115039             2.434176e+08
# CA                        531134             1.619089e+09
#
#                 average_total_payments  average_medicare_payments  \
# provider_state
# AK                        5.705120e+06               4.996261e+06
# AL                        4.119621e+07               3.409628e+07
# AR                        2.707915e+07               2.321937e+07
# AZ                        5.071762e+07               4.397756e+07
# CA                        2.802472e+08               2.466170e+08
#
#                 average_consumer_payments  total_covered_charges  \
# provider_state
# AK                              708859.07           6.644232e+08
# AL                             7099926.01           7.463371e+09
# AR                             3859778.17           3.637367e+09
# AZ                             6740056.79           7.735654e+09
# CA                            33630191.47           5.423888e+10
#
#                 total_payments  total_medicare_payments  \
# provider_state
# AK                1.613549e+08             1.406472e+08
# AL                1.445037e+09             1.182575e+09
# AR                9.448575e+08             8.071309e+08
# AZ                1.634324e+09             1.400898e+09
# CA                9.248171e+09             8.130260e+09
#
#                 total_consumer_payments  per_capita_average_total_payments  \
# provider_state
# AK                         2.070764e+07                           21007.01
# AL                         2.624626e+08                           10172.02
# AR                         1.377266e+08                           10308.85
# AZ                         2.334254e+08                           14206.69
# CA                         1.117911e+09                           17412.12
#
#                 per_capita_average_medicare_payments  \
# provider_state
# AK                                          18311.06
# AL                                           8324.47
# AR                                           8806.18
# AZ                                          12177.60
# CA                                          15307.36
#
#                 per_capita_average_consumer_payments
# provider_state
# AK                                           2695.96
# AL                                           1847.55
# AR                                           1502.66
# AZ                                           2029.10
# CA                                           2104.76

# %%
state_total__payments_grouped = state_grouped["per_capita_average_total_payments"].reset_index()

# %%
state_total__payments_grouped = state_total__payments_grouped.sort_values("per_capita_average_total_payments", ascending=False)

# %%
state_total__payments_grouped.head()
# Out:
#    provider_state  per_capita_average_total_payments
# 0              AK                           21007.01
# 7              DC                           20149.64
# 11             HI                           18959.70
# 4              CA                           17412.12
# 34             NY                           17086.80

# %%
names = []
for name in state_total__payments_grouped["provider_state"]: 
    names.append(name)

# %%
plt.figure(figsize=(15,10))
x_axis = np.arange(len(state_total__payments_grouped["provider_state"]))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, names, rotation="vertical")
plt.bar(x_axis, state_total__payments_grouped["per_capita_average_total_payments"])
plt.grid()
plt.xlabel("State")
plt.ylabel("Average Per Capita Payments ($)")
plt.title("Per Capita Average Total Payments by State")
plt.tight_layout()
plt.savefig("Per Capita Average Total Payments by State")

# %%
#merge cost of living and average payments dframes
merge_cost_average = pd.merge(state_total__payments_grouped, sorted_df, how='outer', on='provider_state')
merge_cost_average.head()
# Out:
#   provider_state  per_capita_average_total_payments  costRank  groceryCost  \
# 0             AK                           21007.01     129.9        134.2
# 1             DC                           20149.64     158.4        115.5
# 2             HI                           18959.70     192.9        169.3
# 3             CA                           17412.12     151.7        121.4
# 4             NY                           17086.80     139.1        114.8
#
#    housingCost  utilitiesCost  transportationCost  miscCost    Total  \
# 0        133.9          154.2               130.8     150.9    80134
# 1        267.0          119.7               116.6      97.3    74444
# 2        318.6          172.7               148.6     116.8   225191
# 3        227.3          117.7               138.9     114.5  5314498
# 4        204.4          108.7               116.6     104.8  3126039
#
#    Original Medicare  Medicare Advantage & Other Health Plans  \
# 0              78805                                     1329
# 1              60015                                    14429
# 2             108107                                   117084
# 3            2825802                                  2488697
# 4            1770649                                  1355390
#
#    Percentage of Medicare Advantage
# 0                               1.7
# 1                              19.4
# 2                              52.0
# 3                              46.8
# 4                              43.4

# %%
#set up scatter plot of average payment vs cost of living
plt.scatter(merge_cost_average['costRank'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Average Payments vs Cost of Living (by state)')
plt.xlabel('Cost of Living')
plt.ylabel('Average Payments')

z = np.polyfit(merge_cost_average['costRank'], 
               merge_cost_average["per_capita_average_total_payments"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average['costRank'], 
           p(merge_cost_average['costRank']),"r")

#save and then show chart
plt.savefig('avgpaymentvscostliving.png')
plt.show()

# %%
pay_cost = merge_cost_average[['costRank', "per_capita_average_total_payments"]]

# %%
#very strong correlation btw cost of living and average payment, as expected
pay_cost.corr()
# Out:
#                                    costRank  per_capita_average_total_payments
# costRank                           1.000000                           0.817891
# per_capita_average_total_payments  0.817891                           1.000000

# %%
#set up scatter plot for transportation vs payments
plt.scatter(merge_cost_average['transportationCost'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Average Payments vs Transportation cost (by state)')
plt.xlabel('Transportation Cost')
plt.ylabel('Average Payments')

z = np.polyfit(merge_cost_average['transportationCost'], 
            merge_cost_average["per_capita_average_total_payments"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average['transportationCost'], p(merge_cost_average['transportationCost']),"r")

#save and then show chart
plt.savefig('avgpaymentvstransportationcost.png')
plt.show()

# %%
transportation = merge_cost_average[["transportationCost", "per_capita_average_total_payments"]]
transportation.corr()
# Out:
#                                    transportationCost  \
# transportationCost                           1.000000
# per_capita_average_total_payments            0.754087
#
#                                    per_capita_average_total_payments
# transportationCost                                          0.754087
# per_capita_average_total_payments                           1.000000

# %%
#set up scatter plot for housing vs payments
plt.scatter(merge_cost_average['housingCost'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Average Payments vs Housing cost (by state)')
plt.xlabel('Housing Cost')
plt.ylabel('Average Payments')

z = np.polyfit(merge_cost_average['housingCost'], 
               merge_cost_average["per_capita_average_total_payments"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average['housingCost'], p(merge_cost_average['housingCost']),"r")

#save and then show chart
plt.savefig('avgpaymentvshousingcost.png')
plt.show()

# %%
#set up scatter plot for utilities vs payments
plt.scatter(merge_cost_average['utilitiesCost'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Average Payments vs Utility cost (by state)')
plt.xlabel('Utility Cost')
plt.ylabel('Average Payments')

z = np.polyfit(merge_cost_average['utilitiesCost'], 
            merge_cost_average["per_capita_average_total_payments"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average['utilitiesCost'], p(merge_cost_average['utilitiesCost']),"r")

#save and then show chart
plt.savefig('avgpaymentvsutilitycost.png')
plt.show()

# %%
#set up scatter plot for misc cost vs payments
plt.scatter(merge_cost_average['miscCost'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Average Payments vs Misc cost (by state)')
plt.xlabel('Misc Cost')
plt.ylabel('Average Payments')

z = np.polyfit(merge_cost_average['miscCost'], 
            merge_cost_average["per_capita_average_total_payments"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average['miscCost'], p(merge_cost_average['miscCost']),"r")

#save and then show chart
# plt.savefig('avgpaymentvsmisccost.png')
plt.show()

# %%
#set up scatter plot to show relationship between housing and total cost of living- strong correlation
#this doesn't really mean anything, but it's a nice graph to look at
plt.scatter(cost_living['housingCost'], cost_living['costRank'], edgecolor='k')
plt.grid(True)
plt.title('total cost of living vs Housing cost (by state)')
plt.xlabel('Housing Cost')
plt.ylabel('total cost of living')

#save and then show chart
# plt.savefig('avgpaymentvscostliving.png')
plt.show()

# %%
#housing is a large driver of cost of living
cost_housing =cost_living[['housingCost', 'costRank']]
cost_housing.corr()
# Out:
#              housingCost  costRank
# housingCost     1.000000  0.981318
# costRank        0.981318  1.000000

# %%
#set up scatter plot for number of medicare enrollees by state vs payments
plt.scatter(merge_cost_average['Total'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Number of Total Medicare Enrollees vs Average Total Payments (by state)')
plt.xlabel('Total Enrollees')
plt.ylabel('Average Payments')

#save and then show chart
plt.savefig('enrolleesvstotalpayments.png')
plt.show()

# %%
#no correlation between number of Med participants in a state vs average payment in that state
tot_enrollees = merge_cost_average[['Total', "per_capita_average_total_payments"]]
tot_enrollees.corr()
# Out:
#                                       Total  per_capita_average_total_payments
# Total                              1.000000                          -0.023086
# per_capita_average_total_payments -0.023086                           1.000000

# %%
#set up scatter plot for number of medicare enrollees by state vs payments
plt.scatter(merge_cost_average['Medicare Advantage & Other Health Plans'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Number of Medicare Adv. Enrollees vs Avg Total Payments (by state)')
plt.xlabel('Medicare Advantage Enrollees')
plt.ylabel('Average Payments')

#save and then show chart
plt.savefig('avgpaymentvspremiummembers.png')
plt.show()

# %%
#no correlation
med_advantage = merge_cost_average[['Medicare Advantage & Other Health Plans', "per_capita_average_total_payments"]]
med_advantage.corr()
# Out:
#                                          Medicare Advantage & Other Health Plans  \
# Medicare Advantage & Other Health Plans                                 1.000000
# per_capita_average_total_payments                                       0.040901
#
#                                          per_capita_average_total_payments
# Medicare Advantage & Other Health Plans                           0.040901
# per_capita_average_total_payments                                 1.000000

# %%
#set up scatter plot for number of 'original' medicare enrollees by state vs payments
plt.scatter(merge_cost_average['Original Medicare'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('Number of Original Medicare Enrollees vs Average Total Payments (by state)')
plt.xlabel('Original Medicare Enrollees')
plt.ylabel('Average Payments')

# z = np.polyfit(merge_cost_average['housingCost'], 
#                merge_cost_average["per capita average total payments"], 1)
# p = np.poly1d(z)
# pylab.plot(merge_cost_average['housingCost'], p(merge_cost_average['housingCost']),"r")

#save and then show chart
# plt.savefig('avgpaymentvsorigmedmembers.png')
plt.show()

# %%
original = merge_cost_average[['Original Medicare', "per_capita_average_total_payments"]]
original.corr()
# Out:
#                                    Original Medicare  \
# Original Medicare                           1.000000
# per_capita_average_total_payments          -0.074288
#
#                                    per_capita_average_total_payments
# Original Medicare                                          -0.074288
# per_capita_average_total_payments                           1.000000

# %%
#set up scatter plot for percentage of medicare advantage enrollees by state vs payments
plt.scatter(merge_cost_average['Percentage of Medicare Advantage'], merge_cost_average["per_capita_average_total_payments"], edgecolor='k')
plt.grid(True)
plt.title('% Medicare Advantage Enrollees vs Avg Total Payments (by state)')
plt.xlabel('Percentage of Med Adv Enrollees')
plt.ylabel('Average Payments')

#save and then show chart
plt.savefig('avgpymntandmedadvperc.png')
plt.show()

# %%
#nope
med_adv = merge_cost_average[["Percentage of Medicare Advantage", "per_capita_average_total_payments"]]
med_adv.corr()
# Out:
#                                    Percentage of Medicare Advantage  \
# Percentage of Medicare Advantage                           1.000000
# per_capita_average_total_payments                         -0.003639
#
#                                    per_capita_average_total_payments
# Percentage of Medicare Advantage                           -0.003639
# per_capita_average_total_payments                           1.000000

# %% [markdown]
#   # Observations:
#     * Alaska, Hawaii, District of Columbia, California and New York pay the most per discharge for sample group.
#     * Mississippi, Alabama and Arkansas spend the least per capita
#     * Alaska(most: over $20,000) spends more than twice as much as Mississippi (least: under $10,000)

# %%
state_medicare_grouped = state_grouped["per_capita_average_medicare_payments"].reset_index()

# %%
state_medicare_grouped = state_medicare_grouped.sort_values("per_capita_average_medicare_payments", ascending=False)

# %%
state_medicare_grouped.head()
# Out:
#    provider_state  per_capita_average_medicare_payments
# 0              AK                              18311.06
# 7              DC                              15618.31
# 4              CA                              15307.36
# 20             MD                              15009.39
# 11             HI                              14891.39

# %%
names = []
for name in state_medicare_grouped["provider_state"]: 
    names.append(name)

# %%
plt.figure(figsize=(15,10))
x_axis = np.arange(len(state_medicare_grouped["provider_state"]))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, names, rotation="vertical")
plt.bar(x_axis, state_medicare_grouped["per_capita_average_medicare_payments"])
plt.grid()
plt.xlabel("State")
plt.ylabel("Average Per Capita Payments ($)")
plt.title("Per Capita Average Medicare Payments by State")
plt.tight_layout()
plt.savefig("Per Capita Average Medicare Payments by State")

# %%
#merge cost of living with grouped by medicare payout df
merge_cost_average_medpay = pd.merge(state_medicare_grouped, sorted_df, how='outer', on='provider_state')
merge_cost_average_medpay.head()
# Out:
#   provider_state  per_capita_average_medicare_payments  costRank  groceryCost  \
# 0             AK                              18311.06     129.9        134.2
# 1             DC                              15618.31     158.4        115.5
# 2             CA                              15307.36     151.7        121.4
# 3             MD                              15009.39     129.7        108.5
# 4             HI                              14891.39     192.9        169.3
#
#    housingCost  utilitiesCost  transportationCost  miscCost    Total  \
# 0        133.9          154.2               130.8     150.9    80134
# 1        267.0          119.7               116.6      97.3    74444
# 2        227.3          117.7               138.9     114.5  5314498
# 3        184.5          107.3               116.7      89.2   854840
# 4        318.6          172.7               148.6     116.8   225191
#
#    Original Medicare  Medicare Advantage & Other Health Plans  \
# 0              78805                                     1329
# 1              60015                                    14429
# 2            2825802                                  2488697
# 3             743622                                   111218
# 4             108107                                   117084
#
#    Percentage of Medicare Advantage
# 0                               1.7
# 1                              19.4
# 2                              46.8
# 3                              13.0
# 4                              52.0

# %%
#set up scatter plot of medicare payments vs cost of living
plt.scatter(merge_cost_average_medpay['costRank'], merge_cost_average_medpay["per_capita_average_medicare_payments"], edgecolor='k')
plt.grid(True)
plt.title('Average Medicare Payments vs Cost of Living (by state)')
plt.xlabel('Cost of Living')
plt.ylabel('Average Medicare Payments')

z = np.polyfit(merge_cost_average_medpay['costRank'], 
            merge_cost_average_medpay["per_capita_average_medicare_payments"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average_medpay['costRank'], p(merge_cost_average_medpay['costRank']),"r")

#save and then show chart
plt.savefig('medicarepaymentvscostliving.png')
plt.show()

# %%
#set up scatter plot for number of medicare enrollees by state vs payments
plt.scatter(merge_cost_average_medpay['Total'], merge_cost_average_medpay["per_capita_average_medicare_payments"], edgecolor='k')
plt.grid(True)
plt.title('Number of Medicare Enrollees vs Average Medicare Payments (by state)')
plt.xlabel('Total Enrollees')
plt.ylabel('Average Payments')

# z = np.polyfit(merge_cost_average['housingCost'], 
#                merge_cost_average["per capita Medica payments"], 1)
# p = np.poly1d(z)
# pylab.plot(merge_cost_average['housingCost'], p(merge_cost_average['housingCost']),"r")

#save and then show chart
# plt.savefig('avgmedpaywenrollees.png')
plt.show()

# %%
state_consumer_payment_grouped = state_grouped["per_capita_average_consumer_payments"].reset_index()

# %%
state_consumer_payment_grouped = state_consumer_payment_grouped.sort_values("per_capita_average_consumer_payments", ascending=False)

# %%
state_consumer_payment_grouped.head()
# Out:
#    provider_state  per_capita_average_consumer_payments
# 7              DC                               4531.33
# 11             HI                               4068.31
# 44             UT                               2909.63
# 8              DE                               2808.60
# 38             PA                               2771.77

# %%
names = []
for name in state_consumer_payment_grouped["provider_state"]: 
    names.append(name)

# %%
plt.figure(figsize=(15,10))
x_axis = np.arange(len(state_consumer_payment_grouped["provider_state"]))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, names, rotation="vertical")
plt.bar(x_axis, state_consumer_payment_grouped["per_capita_average_consumer_payments"])
plt.grid()
plt.xlabel("State")
plt.ylabel("Average Per Capita Consumer Payments ($)")
plt.title("Per Capita Average Consumer Payments by State")
plt.tight_layout()
plt.savefig("Per Capita Average Consumer Payments by State")

# %%
#merge cost of living with grouped by consumer payout df
merge_cost_average_consumer = pd.merge(state_consumer_payment_grouped, sorted_df, how='outer', on='provider_state')
merge_cost_average_consumer.head()
# Out:
#   provider_state  per_capita_average_consumer_payments  costRank  groceryCost  \
# 0             DC                               4531.33     158.4        115.5
# 1             HI                               4068.31     192.9        169.3
# 2             UT                               2909.63      98.4         98.5
# 3             DE                               2808.60     108.1        113.4
# 4             PA                               2771.77     101.7        106.9
#
#    housingCost  utilitiesCost  transportationCost  miscCost    Total  \
# 0        267.0          119.7               116.6      97.3    74444
# 1        318.6          172.7               148.6     116.8   225191
# 2         93.6           89.4               108.6      96.0   333828
# 3         98.2           96.5               107.0     101.6   179142
# 4        100.8          106.0               109.5      91.9  2410301
#
#    Original Medicare  Medicare Advantage & Other Health Plans  \
# 0              60015                                    14429
# 1             108107                                   117084
# 2             202482                                   131346
# 3             156719                                    22423
# 4            1333311                                  1076990
#
#    Percentage of Medicare Advantage
# 0                              19.4
# 1                              52.0
# 2                              39.3
# 3                              12.5
# 4                              44.7

# %%
#set up scatter plot of consumer payments vs cost of living
plt.scatter(merge_cost_average_consumer['costRank'], merge_cost_average_consumer["per_capita_average_consumer_payments"], edgecolor='k')
plt.grid(True)
plt.title('Average Consumer Payments vs Cost of Living (by state)')
plt.xlabel('Cost of Living')
plt.ylabel('Average Consumer Payments')

z = np.polyfit(merge_cost_average_consumer['costRank'], 
                                     merge_cost_average_consumer["per_capita_average_consumer_payments"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average_consumer['costRank'],p(merge_cost_average_consumer['costRank']),"r-")

#save and then show chart
# plt.savefig('consumerpaymentvscostliving.png')
plt.show()

# %%
#set up scatter plot for number of medicare enrollees by state vs consumer payments
plt.scatter(merge_cost_average_consumer['Total'], merge_cost_average_consumer["per_capita_average_consumer_payments"], edgecolor='k')
plt.grid(True)
plt.title('Number of Total Medicare Enrollees vs Average Consumer Payments (by state)')
plt.xlabel('Total Enrollees')
plt.ylabel('Average Consumer Payments')

#save and then show chart
plt.show()

# %%
#no correlation
consumer = merge_cost_average_consumer[["Total", "per_capita_average_consumer_payments"]]
consumer.corr()
# Out:
#                                          Total  \
# Total                                 1.000000
# per_capita_average_consumer_payments -0.052405
#
#                                       per_capita_average_consumer_payments
# Total                                                            -0.052405
# per_capita_average_consumer_payments                              1.000000

# %%
#set up scatter plot for percentage of medicare advatage enrollees by state vs consumer payments
plt.scatter(merge_cost_average_consumer['Percentage of Medicare Advantage'], 
            merge_cost_average_consumer["per_capita_average_consumer_payments"], edgecolor='k')
plt.grid(True)
plt.title('Percentage of Medicare Advantage Enrollees vs Average Consumer Payments (by state)')
plt.xlabel('Percentage Med Adv Enrollees')
plt.ylabel('Average Consumer Payments')

#save and then show chart
plt.show()

# %%
#no correlation
cons_med_adv = merge_cost_average_consumer[["Percentage of Medicare Advantage", "per_capita_average_consumer_payments"]]
cons_med_adv.corr()
# Out:
#                                       Percentage of Medicare Advantage  \
# Percentage of Medicare Advantage                              1.000000
# per_capita_average_consumer_payments                          0.186348
#
#                                       per_capita_average_consumer_payments
# Percentage of Medicare Advantage                                  0.186348
# per_capita_average_consumer_payments                              1.000000

# %%
provider_name_grouped = data_2017.groupby("provider_name").sum()

# %%
provider_name_grouped.head()
# Out:
#                                  total_discharges  average_covered_charges  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                    299                343081.44
# ABBOTT NORTHWESTERN HOSPITAL                11667              15208635.72
# ABILENE REGIONAL MEDICAL CENTER              1374               3786717.62
# ABINGTON MEMORIAL HOSPITAL                   8433              12997767.53
# ABRAZO ARROWHEAD CAMPUS                      2923               8671824.96
#
#                                  average_total_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                    108849.95
# ABBOTT NORTHWESTERN HOSPITAL                 4308641.94
# ABILENE REGIONAL MEDICAL CENTER               454610.80
# ABINGTON MEMORIAL HOSPITAL                   2977841.70
# ABRAZO ARROWHEAD CAMPUS                      1613372.12
#
#                                  average_medicare_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                        94973.98
# ABBOTT NORTHWESTERN HOSPITAL                    3864361.89
# ABILENE REGIONAL MEDICAL CENTER                  392648.76
# ABINGTON MEMORIAL HOSPITAL                      2426369.23
# ABRAZO ARROWHEAD CAMPUS                         1479389.00
#
#                                  average_consumer_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                        13875.97
# ABBOTT NORTHWESTERN HOSPITAL                     444280.05
# ABILENE REGIONAL MEDICAL CENTER                   61962.04
# ABINGTON MEMORIAL HOSPITAL                       551472.47
# ABRAZO ARROWHEAD CAMPUS                          133983.12
#
#                                  total_covered_charges  total_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                7.901825e+06    2.532882e+06
# ABBOTT NORTHWESTERN HOSPITAL              6.873321e+08    1.966408e+08
# ABILENE REGIONAL MEDICAL CENTER           1.152814e+08    1.350601e+07
# ABINGTON MEMORIAL HOSPITAL                4.447002e+08    1.033201e+08
# ABRAZO ARROWHEAD CAMPUS                   2.586292e+08    4.803188e+07
#
#                                  total_medicare_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                  2.226853e+06
# ABBOTT NORTHWESTERN HOSPITAL                1.746274e+08
# ABILENE REGIONAL MEDICAL CENTER             1.167230e+07
# ABINGTON MEMORIAL HOSPITAL                  8.226787e+07
# ABRAZO ARROWHEAD CAMPUS                     4.384264e+07
#
#                                  total_consumer_payments
# provider_name
# ABBEVILLE GENERAL HOSPITAL                     306028.80
# ABBOTT NORTHWESTERN HOSPITAL                 22013400.79
# ABILENE REGIONAL MEDICAL CENTER               1833707.21
# ABINGTON MEMORIAL HOSPITAL                   21052277.40
# ABRAZO ARROWHEAD CAMPUS                       4189232.48

# %%
provider_name_grouped["per capita average total payments"] = round(provider_name_grouped["total_payments"]/provider_name_grouped["total_discharges"], 2)
provider_name_grouped["per capita average medicare payments"] = round(provider_name_grouped["total_medicare_payments"]/provider_name_grouped["total_discharges"], 2)
provider_name_grouped["per capita average consumer payments"] = round(provider_name_grouped["total_consumer_payments"]/provider_name_grouped["total_discharges"], 2)

# %%
provider_name_grouped.head()
# Out:
#                                  total_discharges  average_covered_charges  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                    299                343081.44
# ABBOTT NORTHWESTERN HOSPITAL                11667              15208635.72
# ABILENE REGIONAL MEDICAL CENTER              1374               3786717.62
# ABINGTON MEMORIAL HOSPITAL                   8433              12997767.53
# ABRAZO ARROWHEAD CAMPUS                      2923               8671824.96
#
#                                  average_total_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                    108849.95
# ABBOTT NORTHWESTERN HOSPITAL                 4308641.94
# ABILENE REGIONAL MEDICAL CENTER               454610.80
# ABINGTON MEMORIAL HOSPITAL                   2977841.70
# ABRAZO ARROWHEAD CAMPUS                      1613372.12
#
#                                  average_medicare_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                        94973.98
# ABBOTT NORTHWESTERN HOSPITAL                    3864361.89
# ABILENE REGIONAL MEDICAL CENTER                  392648.76
# ABINGTON MEMORIAL HOSPITAL                      2426369.23
# ABRAZO ARROWHEAD CAMPUS                         1479389.00
#
#                                  average_consumer_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                        13875.97
# ABBOTT NORTHWESTERN HOSPITAL                     444280.05
# ABILENE REGIONAL MEDICAL CENTER                   61962.04
# ABINGTON MEMORIAL HOSPITAL                       551472.47
# ABRAZO ARROWHEAD CAMPUS                          133983.12
#
#                                  total_covered_charges  total_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                7.901825e+06    2.532882e+06
# ABBOTT NORTHWESTERN HOSPITAL              6.873321e+08    1.966408e+08
# ABILENE REGIONAL MEDICAL CENTER           1.152814e+08    1.350601e+07
# ABINGTON MEMORIAL HOSPITAL                4.447002e+08    1.033201e+08
# ABRAZO ARROWHEAD CAMPUS                   2.586292e+08    4.803188e+07
#
#                                  total_medicare_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                  2.226853e+06
# ABBOTT NORTHWESTERN HOSPITAL                1.746274e+08
# ABILENE REGIONAL MEDICAL CENTER             1.167230e+07
# ABINGTON MEMORIAL HOSPITAL                  8.226787e+07
# ABRAZO ARROWHEAD CAMPUS                     4.384264e+07
#
#                                  total_consumer_payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                     306028.80
# ABBOTT NORTHWESTERN HOSPITAL                 22013400.79
# ABILENE REGIONAL MEDICAL CENTER               1833707.21
# ABINGTON MEMORIAL HOSPITAL                   21052277.40
# ABRAZO ARROWHEAD CAMPUS                       4189232.48
#
#                                  per capita average total payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                                 8471.18
# ABBOTT NORTHWESTERN HOSPITAL                              16854.44
# ABILENE REGIONAL MEDICAL CENTER                            9829.70
# ABINGTON MEMORIAL HOSPITAL                                12251.89
# ABRAZO ARROWHEAD CAMPUS                                   16432.39
#
#                                  per capita average medicare payments  \
# provider_name
# ABBEVILLE GENERAL HOSPITAL                                    7447.67
# ABBOTT NORTHWESTERN HOSPITAL                                 14967.63
# ABILENE REGIONAL MEDICAL CENTER                               8495.13
# ABINGTON MEMORIAL HOSPITAL                                    9755.47
# ABRAZO ARROWHEAD CAMPUS                                      14999.19
#
#                                  per capita average consumer payments
# provider_name
# ABBEVILLE GENERAL HOSPITAL                                    1023.51
# ABBOTT NORTHWESTERN HOSPITAL                                  1886.81
# ABILENE REGIONAL MEDICAL CENTER                               1334.58
# ABINGTON MEMORIAL HOSPITAL                                    2496.42
# ABRAZO ARROWHEAD CAMPUS                                       1433.20

# %%
provider_average_total_payments = provider_name_grouped["per capita average total payments"].reset_index()

# %%
provider_average_total_payments = provider_average_total_payments.sort_values("per capita average total payments", ascending=False).head(n=20)

# %%
provider_average_total_payments.head()
# Out:
#                           provider_name  per capita average total payments
# 2901           US PAIN & SPINE HOSPITAL                           72224.09
# 3056       WOMANS HOSPITAL OF TEXAS,THE                           59889.09
# 2594         STERLING SURGICAL HOSPITAL                           52988.47
# 608   CRESCENT MEDICAL CENTER LANCASTER                           48538.18
# 1265         LAC/HARBOR-UCLA MED CENTER                           45043.31

# %%
names = []
for name in provider_average_total_payments["provider_name"]: 
    names.append(name)

# %%
plt.figure(figsize=(20,10))
x_axis = np.arange(len(provider_average_total_payments["provider_name"]))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, names, rotation="vertical")
plt.bar(x_axis, provider_average_total_payments["per capita average total payments"])
plt.grid()
plt.xlabel("Provider")
plt.ylabel("Average Per Capita total Payments ($)")
plt.title("Per Capita Average total Payments by Provider")
plt.tight_layout()
plt.savefig("Per Capita Average total Payments by Provider")

# %%
average_covered_charges = data_2017.groupby("provider_state").sum()
average_covered_charges.head()
# Out:
#                 total_discharges  average_covered_charges  \
# provider_state
# AK                          7681             2.337966e+07
# AL                        142060             2.143038e+08
# AR                         91655             1.058598e+08
# AZ                        115039             2.434176e+08
# CA                        531134             1.619089e+09
#
#                 average_total_payments  average_medicare_payments  \
# provider_state
# AK                        5.705120e+06               4.996261e+06
# AL                        4.119621e+07               3.409628e+07
# AR                        2.707915e+07               2.321937e+07
# AZ                        5.071762e+07               4.397756e+07
# CA                        2.802472e+08               2.466170e+08
#
#                 average_consumer_payments  total_covered_charges  \
# provider_state
# AK                              708859.07           6.644232e+08
# AL                             7099926.01           7.463371e+09
# AR                             3859778.17           3.637367e+09
# AZ                             6740056.79           7.735654e+09
# CA                            33630191.47           5.423888e+10
#
#                 total_payments  total_medicare_payments  \
# provider_state
# AK                1.613549e+08             1.406472e+08
# AL                1.445037e+09             1.182575e+09
# AR                9.448575e+08             8.071309e+08
# AZ                1.634324e+09             1.400898e+09
# CA                9.248171e+09             8.130260e+09
#
#                 total_consumer_payments
# provider_state
# AK                         2.070764e+07
# AL                         2.624626e+08
# AR                         1.377266e+08
# AZ                         2.334254e+08
# CA                         1.117911e+09

# %%
average_covered_charges["per capita average covered charges"] = average_covered_charges["total_covered_charges"]/average_covered_charges["total_discharges"]

# %%
average_covered_charges = average_covered_charges["per capita average covered charges"].reset_index()

# %%
average_covered_charges = average_covered_charges.sort_values("per capita average covered charges", ascending=False)

# %%
average_covered_charges.head()
# Out:
#    provider_state  per capita average covered charges
# 4              CA                       102119.017717
# 33             NV                        92049.817804
# 0              AK                        86502.175326
# 31             NJ                        83481.968550
# 7              DC                        77743.054907

# %%
names = []
for name in average_covered_charges["provider_state"]: 
    names.append(name)

# %%
plt.figure(figsize=(15,10))
x_axis = np.arange(len(average_covered_charges["provider_state"]))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, names, rotation="vertical")
plt.bar(x_axis, average_covered_charges["per capita average covered charges"])
plt.grid()
plt.xlabel("State")
plt.ylabel("Average Per Capita Covered Charges ($)")
plt.title("Per Capita Average Covered Charges by State")
plt.tight_layout()
plt.savefig("Per Capita Average Covered Charges by State")

# %%
#merge cost of living with grouped by covered charges df
merge_cost_covered_charges = pd.merge(average_covered_charges, sorted_df, how='outer', on='provider_state')
merge_cost_covered_charges.head()
# Out:
#   provider_state  per capita average covered charges  costRank  groceryCost  \
# 0             CA                       102119.017717     151.7        121.4
# 1             NV                        92049.817804     108.5        108.3
# 2             AK                        86502.175326     129.9        134.2
# 3             NJ                        83481.968550     125.1        109.5
# 4             DC                        77743.054907     158.4        115.5
#
#    housingCost  utilitiesCost  transportationCost  miscCost    Total  \
# 0        227.3          117.7               138.9     114.5  5314498
# 1        121.8           89.0               123.5     105.7   439722
# 2        133.9          154.2               130.8     150.9    80134
# 3        163.1          101.6               111.1     101.7  1381564
# 4        267.0          119.7               116.6      97.3    74444
#
#    Original Medicare  Medicare Advantage & Other Health Plans  \
# 0            2825802                                  2488697
# 1             266673                                   173049
# 2              78805                                     1329
# 3            1042780                                   338785
# 4              60015                                    14429
#
#    Percentage of Medicare Advantage
# 0                              46.8
# 1                              39.4
# 2                               1.7
# 3                              24.5
# 4                              19.4

# %%
#set up scatter plot of covered costs vs cost of living
plt.scatter(merge_cost_covered_charges['costRank'], merge_cost_covered_charges["per capita average covered charges"], edgecolor='k')
plt.grid(True)
plt.title('Average Covered Medicare Charges vs Cost of Living (by state)')
plt.xlabel('Cost of Living')
plt.ylabel('Average Covered Charges')

z = np.polyfit(merge_cost_covered_charges['costRank'], 
            merge_cost_covered_charges["per capita average covered charges"], 1)
p = np.poly1d(z)
pylab.plot(merge_cost_average_consumer['costRank'],p(merge_cost_average_consumer['costRank']),"r")

#save and then show chart
# plt.savefig('consumerpaymentvscostliving.png')
plt.show()

# %%
#very weak correlation
covered = merge_cost_covered_charges[["costRank", "per capita average covered charges"]]
covered.corr()
# Out:
#                                     costRank  \
# costRank                            1.000000
# per capita average covered charges  0.269679
#
#                                     per capita average covered charges
# costRank                                                      0.269679
# per capita average covered charges                            1.000000

# %% [markdown]
# *Observation:
# *For some reason Maryland has a relatively high total and medicare payments, but low on consumer payment and average covered charge.

# %%
physician_data = pd.merge(state_grouped, physician_data, on="provider_state")

# %%
physician_data.head()
# Out:
#   provider_state  total_discharges  average_covered_charges  \
# 0             AK              7681             2.337966e+07
# 1             AL            142060             2.143038e+08
# 2             AR             91655             1.058598e+08
# 3             AZ            115039             2.434176e+08
# 4             CA            531134             1.619089e+09
#
#    average_total_payments  average_medicare_payments  \
# 0            5.705120e+06               4.996261e+06
# 1            4.119621e+07               3.409628e+07
# 2            2.707915e+07               2.321937e+07
# 3            5.071762e+07               4.397756e+07
# 4            2.802472e+08               2.466170e+08
#
#    average_consumer_payments  total_covered_charges  total_payments  \
# 0                  708859.07           6.644232e+08    1.613549e+08
# 1                 7099926.01           7.463371e+09    1.445037e+09
# 2                 3859778.17           3.637367e+09    9.448575e+08
# 3                 6740056.79           7.735654e+09    1.634324e+09
# 4                33630191.47           5.423888e+10    9.248171e+09
#
#    total_medicare_payments  total_consumer_payments  \
# 0             1.406472e+08             2.070764e+07
# 1             1.182575e+09             2.624626e+08
# 2             8.071309e+08             1.377266e+08
# 3             1.400898e+09             2.334254e+08
# 4             8.130260e+09             1.117911e+09
#
#    per_capita_average_total_payments  per_capita_average_medicare_payments  \
# 0                           21007.01                              18311.06
# 1                           10172.02                               8324.47
# 2                           10308.85                               8806.18
# 3                           14206.69                              12177.60
# 4                           17412.12                              15307.36
#
#    per_capita_average_consumer_payments       State  primary_care_physicians  \
# 0                               2695.96      Alaska                   1054.0
# 1                               1847.55     Alabama                   5863.0
# 2                               1502.66    Arkansas                   3513.0
# 3                               2029.10     Arizona                   8537.0
# 4                               2104.76  California                  54135.0
#
#    specialist_physicians     Total
# 0                  846.0    1900.0
# 1                 6342.0   12205.0
# 2                 3637.0    7150.0
# 3                 9269.0   17806.0
# 4                58771.0  112906.0

# %%
physician_data["per_capita_discharges_per_total_physicians"] = physician_data["total_discharges"]/physician_data["Total"]
physician_data["per_capita_discharges_per_primary_care_physicians"] = physician_data["total_discharges"]/physician_data["primary_care_physicians"]
physician_data["per_capita_discharges_per_specialty_physicians"] = physician_data["total_discharges"]/physician_data["specialist_physicians"]

# %%
physician_data_a = physician_data.sort_values("per_capita_discharges_per_total_physicians", ascending=False)
physician_data_a.head()
# Out:
#    provider_state  total_discharges  average_covered_charges  \
# 25             MS             99670             1.299886e+08
# 41             SD             27264             3.493172e+07
# 2              AR             91655             1.058598e+08
# 17             KY            140856             1.739644e+08
# 1              AL            142060             2.143038e+08
#
#     average_total_payments  average_medicare_payments  \
# 25             27973686.77                24105351.55
# 41              9406980.22                 8097491.54
# 2              27079151.33                23219373.16
# 17             43003849.19                36052850.20
# 1              41196206.60                34096280.59
#
#     average_consumer_payments  total_covered_charges  total_payments  \
# 25                 3868335.22           4.538800e+09    9.818652e+08
# 41                 1309488.68           1.353099e+09    3.649840e+08
# 2                  3859778.17           3.637367e+09    9.448575e+08
# 17                 6950998.99           6.490263e+09    1.610051e+09
# 1                  7099926.01           7.463371e+09    1.445037e+09
#
#     total_medicare_payments  total_consumer_payments  \
# 25             8.403730e+08             1.414922e+08
# 41             3.137980e+08             5.118600e+07
# 2              8.071309e+08             1.377266e+08
# 17             1.343087e+09             2.669641e+08
# 1              1.182575e+09             2.624626e+08
#
#     per_capita_average_total_payments  per_capita_average_medicare_payments  \
# 25                            9851.16                               8431.55
# 41                           13387.03                              11509.61
# 2                            10308.85                               8806.18
# 17                           11430.47                               9535.17
# 1                            10172.02                               8324.47
#
#     per_capita_average_consumer_payments         State  \
# 25                               1419.61   Mississippi
# 41                               1877.42  South Dakota
# 2                                1502.66      Arkansas
# 17                               1895.30      Kentucky
# 1                                1847.55       Alabama
#
#     primary_care_physicians  specialist_physicians    Total  \
# 25                   3216.0                 3381.0   6597.0
# 41                   1083.0                  958.0   2041.0
# 2                    3513.0                 3637.0   7150.0
# 17                   5481.0                 6456.0  11937.0
# 1                    5863.0                 6342.0  12205.0
#
#     per_capita_discharges_per_total_physicians  \
# 25                                   15.108383
# 41                                   13.358158
# 2                                    12.818881
# 17                                   11.799950
# 1                                    11.639492
#
#     per_capita_discharges_per_primary_care_physicians  \
# 25                                          30.991915
# 41                                          25.174515
# 2                                           26.090236
# 17                                          25.698960
# 1                                           24.229916
#
#     per_capita_discharges_per_specialty_physicians
# 25                                       29.479444
# 41                                       28.459290
# 2                                        25.200715
# 17                                       21.817844
# 1                                        22.399874

# %%
#scatter plot for average payments vs average discharges per doctor
physician_data.plot.scatter("per_capita_discharges_per_total_physicians", "per_capita_average_total_payments")
plt.grid(True)
plt.title('Average Payment vs Num of Discharges per Doctor')
plt.xlabel('Discharges per Doctor')
plt.ylabel('Average Payment')

#save and then show chart
plt.savefig('avgpaymentvsdoctordischarges.png')
plt.show()

# %%
physician_corr = physician_data[["per_capita_discharges_per_total_physicians","per_capita_average_total_payments" ]]
physician_corr.corr()
# Out:
#                                             per_capita_discharges_per_total_physicians  \
# per_capita_discharges_per_total_physicians                                    1.000000
# per_capita_average_total_payments                                            -0.732278
#
#                                             per_capita_average_total_payments
# per_capita_discharges_per_total_physicians                          -0.732278
# per_capita_average_total_payments                                    1.000000

# %%
physician_data.plot.scatter("per_capita_discharges_per_primary_care_physicians", "per_capita_average_total_payments")

# %%
physician_corr = physician_data[["per_capita_discharges_per_primary_care_physicians","per_capita_average_total_payments" ]]
physician_corr.corr()

# %%
physician_data.plot.scatter("per_capita_discharges_per_specialty_physicians", "per_capita_average_total_payments")

# %%
physician_corr = physician_data[["per_capita_discharges_per_specialty_physicians","per_capita_average_total_payments" ]]
physician_corr.corr()
